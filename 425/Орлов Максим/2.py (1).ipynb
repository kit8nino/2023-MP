0.4817536741017153), (-0.5968972324554216, 0.8023177013422167), (-0.3363721616190145, 0.9417291377502087), (0.944445227193913, 0.3286688498027125), (-0.974807930206933, -0.223045957608909), (0.3428728403199321, -0.9393818261872764), (0.9325256250568851, 0.36110380586787744), (0.28080072028466513, -0.9597660941539939), (-0.743004666792947, 0.669286235570329), (0.5014503369740864, -0.8651864305157445), (-0.9809687130744494, -0.19416586715758913), (0.5400640630241152, -0.8416239111562149), (0.7697116240044488, -0.6383917417013115), (0.99888987496197, 0.04710645070964266), (0.5620833778521306, -0.8270805742745618), (0.9698209714046908, -0.2438181359613388), (0.23894022441611057, 0.9710342780540647), (-0.04836165522268871, 0.9988298905740265), (0.6232792481669395, 0.7819993470613992), (0.6822536091093965, -0.731115594729864), (0.24929841678407536, -0.9684267134837584), (0.6999625567394806, -0.7141795426660787), (0.9419403007087905, -0.33578038939258087), (-0.5411212521268759, -0.840944582298169), (-0.9984717850692078, 0.05526386179692751), (-0.0878511965507432, 0.9961336091431725), (0.6608404261317916, 0.7505264360367009), (0.710652139642431, -0.7035435568759298), (0.7855113862240121, 0.6188472041727512), (-0.20094114467933777, 0.9796033158248074), (0.04522350508293264, -0.9989768939209825), (0.4545502459987194, -0.8907210976857479), ...

# %%
#отрывок из книги не менее 10000 слов, разбитый в список по словам.
file = 'book.txt'
book = []
with open(file, encoding='utf-8') as file:
    for line in file:
        for i in line.split():
            book.append(i.strip(string.punctuation))
print("Отрывок из книги:", book[:10000])
print("Выбранные сортировки: [5, 13, 2, 8] \n")
def shell_sort(sequence):
    n = len(sequence)
    step = n//2
    while step > 0:
        for i in range(step, n):
            j = i
            while j >= step and sequence[j] < sequence[j-step]:
                sequence[j], sequence[j-step] = sequence[j-step], sequence[j]
                j = j - step
        step = step // 2
    print("Отсортированный список:", sequence)
# Out:
# Отрывок из книги: ['В', 'октябре', '1805', 'года', 'русские', 'войска', 'занимали', 'села', 'и', 'города', 'эрцгерцогства', 'Австрийского', 'и', 'еще', 'новые', 'полки', 'приходили', 'из', 'России', 'и', 'отягощая', 'постоем', 'жителей', 'располагались', 'у', 'крепости', 'Браунау', 'В', 'Браунау', 'была', 'главная', 'квартира', 'главнокомандующего', 'Кутузова', '11-го', 'октября', '1805', 'года', 'один', 'из', 'только', 'что', 'пришедших', 'к', 'Браунау', 'пехотных', 'полков', 'ожидая', 'смотра', 'главнокомандующего', 'стоял', 'в', 'полумиле', 'от', 'города', 'Несмотря', 'на', 'нерусскую', 'местность', 'и', 'обстановку', 'фруктовые', 'сады', 'каменные', 'ограды', 'черепичные', 'крыши', 'горы', 'видневшиеся', 'вдали', '—', 'на', 'нерусский', 'народ', 'с', 'любопытством', 'смотревший', 'на', 'солдат', '—', 'полк', 'имел', 'точно', 'такой', 'же', 'вид', 'какой', 'имел', 'всякий', 'русский', 'полк', 'готовившийся', 'к', 'смотру', 'где-нибудь', 'в', 'середине', 'России', 'С', 'вечера', 'на', 'последнем', 'переходе', 'был', 'получен', 'приказ', 'что', 'главнокомандующий', 'будет', 'смотреть', 'полк', 'на', 'походе', 'Хотя', 'слова', 'приказа', 'и', 'показались', 'неясны', 'полковому', 'командиру', 'и', 'возник', 'вопрос', 'как', 'разуметь', 'слова', 'приказа', 'в', 'походной', 'форме', 'или', 'нет', '—', 'в', 'совете', 'батальонных', 'командиров', 'было', 'решено', 'представить', 'полк', 'в', 'парадной', 'форме', 'на', 'том', 'основании', 'что', 'всегда', 'лучше', 'перекланяться', 'чем', 'недокланяться', 'И', 'солдаты', 'после', 'тридцативерстного', 'перехода', 'не', 'смыкали', 'глаз', 'всю', 'ночь', 'чинились', 'чистились', 'адъютанты', 'и', 'ротные', 'рассчитывали', 'отчисляли', 'и', 'к', 'утру', 'полк', 'вместо', 'растянутой', 'беспорядочной', 'толпы', 'какою', 'он', 'был', 'накануне', 'на', 'последнем', 'переходе', 'представлял', 'стройную', 'массу', 'двух', 'тысяч', 'людей', 'из', 'которых', 'каждый', 'знал', 'свое', 'место', 'свое', 'дело', 'из', 'которых', 'на', 'каждом', 'каждая', 'пуговка', 'и', 'ремешок', 'были', 'на', 'своем', 'месте', 'и', 'блестели', 'чистотой', 'Не', 'только', 'наружное', 'было', 'исправно', 'но', 'ежели', 'бы', 'угодно', 'было', 'главнокомандующему', 'заглянуть', 'под', 'мундиры', 'то', 'на', 'каждом', 'он', 'увидел', 'бы', 'одинаково', 'чистую', 'рубаху', 'и', 'в', 'каждом', 'ранце', 'нашел', 'бы', 'узаконенное', 'число', 'вещей', '«шильце', 'и', 'мыльце»', 'как', 'говорят', 'солдаты', 'Было', 'только', 'одно', 'обстоятельство', 'насчет', 'которого', 'никто', 'не', 'мог', 'быть', 'спокоен', 'Это', 'была', 'обувь', 'Больше', 'чем', 'у', 'половины', 'людей', 'сапоги', 'были', 'разбиты', 'Но', 'недостаток', 'этот', 'происходил', 'не', 'от', 'вины', 'полкового', 'командира', 'так', 'как', 'несмотря', 'на', 'неоднократные', 'требования', 'ему', 'не', 'был', 'отпущен', 'товар', 'от', 'австрийского', 'ведомства', 'а', 'полк', 'прошел', 'тысячу', 'верст', 'Полковой', 'командир', 'был', 'пожилой', 'сангвинический', 'с', 'седеющими', 'бровями', 'и', 'бакенбардами', 'генерал', 'плотный', 'и', 'широкий', 'больше', 'от', 'груди', 'к', 'спине', 'чем', 'от', 'одного', 'плеча', 'к', 'другому', 'На', 'нем', 'был', 'новый', 'с', 'иголочки', 'со', 'слежавшимися', 'складками', 'мундир', 'и', 'густые', 'золотые', 'эполеты', 'которые', 'как', 'будто', 'не', 'книзу', 'а', 'кверху', 'поднимали', 'его', 'тучные', 'плечи', 'Полковой', 'командир', 'имел', 'вид', 'человека', 'счастливо', 'совершающего', 'одно', 'из', 'самых', 'торжественных', 'дел', 'жизни', 'Он', 'похаживал', 'перед', 'фронтом', 'и', 'похаживая', 'подрагивал', 'на', 'каждом', 'шагу', 'слегка', 'изгибаясь', 'спиною', 'Видно', 'было', 'что', 'полковой', 'командир', 'любуется', 'своим', 'полком', 'счастлив', 'им', 'и', 'что', 'все', 'его', 'силы', 'душевные', 'заняты', 'только', 'полком', 'но', 'несмотря', 'на', 'то', 'его', 'подрагивающая', 'походка', 'как', 'будто', 'говорила', 'что', 'кроме', 'военных', 'интересов', 'в', 'душе', 'его', 'немалое', 'место', 'зан ...
# Выбранные сортировки: [5, 13, 2, 8]

# %%
#Функция для сортировки вставкой выше#
def insertion_sort(sequence):
    for i in range(1, len(sequence)):
        paste_element = sequence[i]
        while i > 0 and sequence[i-1] > paste_element:
            sequence[i] = sequence[i-1]
            i = i-1
        sequence[i] = paste_element

#Функция для поиска минимума и максимума#
def find_min_max(sequence):
    if len(sequence) == 0:
        return [0, 0]
    min_max = [sequence[0], sequence[0]]
    for element in sequence:
        if element < min_max[0]:
            min_max[0] = element
        if element > min_max[1]:
            min_max[1] = element
    return min_max

#Функция для блочной сортировки#
def bucket_sort(sequence, n):
    buckets = []
    for i in range(n):
        buckets.append([])
    min_max = find_min_max(sequence)
    if(min_max[0] == min_max[1]):
        return
    for element in sequence:
        buckets[(n * (element - min_max[0])) //
                (min_max[1]-min_max[0]+1)].append(element)
    for bucket in buckets:
        if(len(bucket) <= 32):
            insertion_sort(bucket)
        else:
            bucket_sort(bucket, n)
    insert_index = 0
    for bucket in buckets:
        for element in bucket:
            sequence[insert_index] = element
            insert_index += 1

def bubble_sort(sequence):
    n = len(sequence)
    for i in range(n):
        for j in range(n-i-1):
            if sequence[j] > sequence[j+1]:
                sequence[j], sequence[j+1] = sequence[j+1], sequence[j]
    return sequence
    n = len(sequence)
    for i in range(n-1):
        min_index = i
        for j in range(i+1, n):
            if sequence[j] < sequence[min_index]:
                min_index = j
        if min_index != i:
            sequence[i], sequence[min_index] = sequence[min_index], sequence[i]
    return sequence

####Выбор списков и сортировок###
sequence = []
print("Выберите список, который хотите отсориторовать:\n 1 - Список целых чисел \n 2 - Список случайных вещественных чисел \n 3 - Точки на комлексной плоскости \n 4 - Отрывок из книги")
number_1 = int(input())

if number_1 == 1:
    sequence = list_of_integers
elif number_1 == 2:
    sequence = random_list_of_real
elif number_1 == 3:
    sequence = points_in_circum
else:
    sequence = book[:10000]

print("Был выбран список:",sequence,"\n")

print("Выберите способ сортировки: \n 1 - Shellsort, сортировка Шелла \n 2 - Bucket sort, блочная сортировка \n 3 - Bubble sort, сортировка пузырьком \n 4 - Selection sort, сортировка выбором")
number_2 = int(input())
print("Обработка... \n")

if number_2 == 1:
    funk = shell_sort(sequence)
elif number_2 == 2 and number_1 == 1:
    find_min_max(sequence)
    funk = bucket_sort(sequence, 4)
    print("Отсортированный список:", sequence)
elif number_2 == 3:
    funk = bubble_sort(sequence)
    print("Отсортированный список:", sequence)
else:
    funk = selection_sort(sequence)
    print("Отсортированный список:", sequence)
# Out:
# Выберите список, который хотите отсориторовать:
#  1 - Список целых чисел
#  2 - Список случайных вещественных чисел
#  3 - Точки на комлексной плоскости
#  4 - Отрывок из книги
# 4
# Был выбран список: ['В', 'октябре', '1805', 'года', 'русские', 'войска', 'занимали', 'села', 'и', 'города', 'эрцгерцогства', 'Австрийского', 'и', 'еще', 'новые', 'полки', 'приходили', 'из', 'России', 'и', 'отягощая', 'постоем', 'жителей', 'располагались', 'у', 'крепости', 'Браунау', 'В', 'Браунау', 'была', 'главная', 'квартира', 'главнокомандующего', 'Кутузова', '11-го', 'октября', '1805', 'года', 'один', 'из', 'только', 'что', 'пришедших', 'к', 'Браунау', 'пехотных', 'полков', 'ожидая', 'смотра', 'главнокомандующего', 'стоял', 'в', 'полумиле', 'от', 'города', 'Несмотря', 'на', 'нерусскую', 'местность', 'и', 'обстановку', 'фруктовые', 'сады', 'каменные', 'ограды', 'черепичные', 'крыши', 'горы', 'видневшиеся', 'вдали', '—', 'на', 'нерусский', 'народ', 'с', 'любопытством', 'смотревший', 'на', 'солдат', '—', 'полк', 'имел', 'точно', 'такой', 'же', 'вид', 'какой', 'имел', 'всякий', 'русский', 'полк', 'готовившийся', 'к', 'смотру', 'где-нибудь', 'в', 'середине', 'России', 'С', 'вечера', 'на', 'последнем', 'переходе', 'был', 'получен', 'приказ', 'что', 'главнокомандующий', 'будет', 'смотреть', 'полк', 'на', 'походе', 'Хотя', 'слова', 'приказа', 'и', 'показались', 'неясны', 'полковому', 'командиру', 'и', 'возник', 'вопрос', 'как', 'разуметь', 'слова', 'приказа', 'в', 'походной', 'форме', 'или', 'нет', '—', 'в', 'совете', 'батальонных', 'командиров', 'было', 'решено', 'представить', 'полк', 'в', 'парадной', 'форме', 'на', 'том', 'основании', 'что', 'всегда', 'лучше', 'перекланяться', 'чем', 'недокланяться', 'И', 'солдаты', 'после', 'тридцативерстного', 'перехода', 'не', 'смыкали', 'глаз', 'всю', 'ночь', 'чинились', 'чистились', 'адъютанты', 'и', 'ротные', 'рассчитывали', 'отчисляли', 'и', 'к', 'утру', 'полк', 'вместо', 'растянутой', 'беспорядочной', 'толпы', 'какою', 'он', 'был', 'накануне', 'на', 'последнем', 'переходе', 'представлял', 'стройную', 'массу', 'двух', 'тысяч', 'людей', 'из', 'которых', 'каждый', 'знал', 'свое', 'место', 'свое', 'дело', 'из', 'которых', 'на', 'каждом', 'каждая', 'пуговка', 'и', 'ремешок', 'были', 'на', 'своем', 'месте', 'и', 'блестели', 'чистотой', 'Не', 'только', 'наружное', 'было', 'исправно', 'но', 'ежели', 'бы', 'угодно', 'было', 'главнокомандующему', 'заглянуть', 'под', 'мундиры', 'то', 'на', 'каждом', 'он', 'увидел', 'бы', 'одинаково', 'чистую', 'рубаху', 'и', 'в', 'каждом', 'ранце', 'нашел', 'бы', 'узаконенное', 'число', 'вещей', '«шильце', 'и', 'мыльце»', 'как', 'говорят', 'солдаты', 'Было', 'только', 'одно', 'обстоятельство', 'насчет', 'которого', 'никто', 'не', 'мог', 'быть', 'спокоен', 'Это', 'была', 'обувь', 'Больше', 'чем', 'у', 'половины', 'людей', 'сапоги', 'были', 'разбиты', 'Но', 'недостаток', 'этот', 'происходил', 'не', 'от', 'вины', 'полкового', 'командира', 'так', 'как', 'несмотря', 'на', 'неоднократные', 'требования', 'ему', 'не', 'был', 'отпущен', 'товар', 'от', 'австрийского', 'ведомства', 'а', 'полк', 'прошел', 'тысячу', 'верст', 'Полковой', 'командир', 'был', 'пожилой', 'сангвинический', 'с', 'седеющими', 'бровями', 'и', 'бакенбардами', 'генерал', 'плотный', 'и', 'широкий', 'больше', 'от', 'груди', 'к', 'спине', 'чем', 'от', 'одного', 'плеча', 'к', 'другому', 'На', 'нем', 'был', 'новый', 'с', 'иголочки', 'со', 'слежавшимися', 'складками', 'мундир', 'и', 'густые', 'золотые', 'эполеты', 'которые', 'как', 'будто', 'не', 'книзу', 'а', 'кверху', 'поднимали', 'его', 'тучные', 'плечи', 'Полковой', 'командир', 'имел', 'вид', 'человека', 'счастливо', 'совершающего', 'одно', 'из', 'самых', 'торжественных', 'дел', 'жизни', 'Он', 'похаживал', 'перед', 'фронтом', 'и', 'похаживая', 'подрагивал', 'на', 'каждом', 'шагу', 'слегка', 'изгибаясь', 'спиною', 'Видно', 'было', 'что', 'полковой', 'командир', 'любуется', 'своим', 'полком', 'счастлив', 'им', 'и', 'что', 'все', 'его', 'силы', 'душевные', 'заняты', 'только', 'полком', 'но', 'несмотря', 'на', 'то', 'его', 'подрагивающая', 'походка', 'как', 'будто', 'говорила', 'что', 'кроме', 'военных', 'интересов', 'в', 'душе', 'его', 'немалое', 'место', 'за ...
#
# Выберите способ сортировки:
#  1 - Shellsort, сортировка Шелла
#  2 - Bucket sort, блочная сортировка
#  3 - Bubble sort, сортировка пузырьком
#  4 - Selection sort, сортировка выбором
# 1
# Обработка...
#
# Отсортированный список: ['11-го', '1805', '1805', '3-й', '3-й', '3-ю', '3-ю', '«Выпускала', '«Здравья', '«Каменскиим-отцом»', '«Кутузовым-отцом»', '«Не', '«Сени', '«То-то', '«ваше', '«генерала', '«шильце', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'А', 'Австрии', 'Австрийского', 'Австрияк', 'Адъютант', 'Андрей', 'Андрей', 'Ах', 'Ах', 'Барабанщик-запевало', 'Батальонный', 'Бахусу', 'Благодарю', 'Ближе', 'Бог', 'Бог', 'Богу', 'Бойкая', 'Болконский', 'Больше', 'Браунау', 'Браунау', 'Браунау', 'Браунау', 'Браунау', 'Брунове', 'Брунове', 'Будь', 'Бунапарт', 'Бунапарт', 'Бунапарт', 'Бунапартом', 'Было', 'В', 'В', 'В', 'В', 'В', 'Вам', 'Вам', 'Ваше', 'Ваше', 'Ваше', 'Ваше', 'Ваше', 'Ведь', 'Вены', 'Видно', 'Видно', 'Видно', 'Вишь', 'Во', 'Во', 'Вовсе', 'Вот', 'Вот', 'Вы', 'Вы', 'Вы', 'Выслушав', 'Где', 'Где', 'Генерал', 'Генерал', 'Главнокомандующий', 'Глаза', 'Говорили', 'Голубые', 'Господа', 'Господа', 'Государь', 'Гусарский', 'Гусарский', 'Гусарский', 'Да', 'Да', 'Да', 'Да', 'Дай', 'До', 'Долой', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохов', 'Долохова', 'Долохова', 'Долохова', 'Долохова', 'Долохове', 'Долохову', 'Долохову', 'Друг', 'Едет', 'Едешь', 'Еще', 'Жерков', 'Жерков', 'Жерков', 'Жерков', 'Жерков', 'Жерков', 'Жерков', 'За', 'За', 'Зарок', 'Зачем', 'И', 'И', 'И', 'И', 'И', 'И', 'И', 'И', 'И', 'И', 'И', 'И', 'Игнатьич', 'Извольте', 'Извольте', 'Измаилом', 'Или', 'К', 'Ка-а-ак', 'Каждый', 'Казалось', 'Как', 'Как', 'Как', 'Как', 'Как', 'Каменскиим-отцом...»', 'Князь', 'Когда', 'Коляска', 'Командир', 'Командира', 'Кто', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузов', 'Кутузова', 'Кутузова', 'Кутузова', 'Кутузова', 'Кутузова', 'Кутузова', 'Кутузову', 'Лицо', 'Лицо', 'Лугу', 'Людям', 'Мака', 'Митрич', 'Митрич', 'Михайло', 'Михайло', 'Мне', 'Мы', 'На', 'На', 'На', 'На', 'Наделали', 'Надеюсь', 'Находит', 'Не', 'Не', 'Не', 'Не', 'Не', 'Не', 'Нельзя', 'Несвицкий', 'Несвицкий', 'Несвицкий', 'Несвицкий', 'Несмотря', 'Ничего', 'Но', 'Но', 'Нога', 'Ну', 'Ну', 'Ну', 'Ну', 'Ну', 'Ну', 'Ну', 'Ну', 'Ну', 'Об', 'Оборвав', 'Однако', 'Одно', 'Ожидается', 'Он', 'Он', 'Он', 'Он', 'Он', 'Они', 'Опять', 'Оторвав', 'Отсталых', 'Офицер', 'Очень', 'Очень', 'Переодеть', 'Песенники', 'Песня', 'Петербурге', 'По', 'По', 'По', 'По', 'Поглядывая', 'Подле', 'Полк', 'Полк', 'Полк', 'Полк', 'Полковой', 'Полковой', 'Полковой', 'Полковой', 'Полковой', 'Полковой', 'Полковой', 'Полковой', 'Полковой', 'Полковой', 'Польше', 'Помилуйте', 'Поравнявшись', 'Потом', 'Претензия', 'Прикомандирован', 'Приходи', 'Прохор', 'Прошу', 'Прощай', 'Пятая', 'Разговор', 'Раздался', 'Разрешил', 'Разрешил', 'Разрешил', 'России', 'России', 'России', 'России', 'Рота', 'Ротные', 'Ротный', 'Рядом', 'С', 'С', 'Сам', 'Сами', 'Свита', 'Сзади', 'Сзади', 'Скоро', 'Слава', 'Служба', 'Слушаю', 'Смир-р-р-на', 'Сначала', 'Со', 'Со', 'Солдаты', 'Стройная', 'Счастливое', 'Так', 'Там', 'Там', 'Теперь', 'Теперь', 'Тимохин', 'Тимохин', 'Тимохин', 'Тимохин', 'Тимохин', 'Тимохина', 'Тимохину', 'То-то', 'То-то', 'То-то', 'Третья', 'Турции', 'Ты', 'Ты', 'Ты', 'Ты', 'У', 'Успеем', 'Федешоу', 'Фельдфебелей', 'Фельдфебель', 'Фердинанда', 'Хоть', 'Хотя', 'Хотя', 'Храбрый', 'Царицыном', 'Чего', 'Через', 'Через', 'Что', 'Что', 'Что', 'Что', 'Что', 'Что', 'Это', 'Это', 'Это', 'Это', 'Это', 'Это', 'Я', 'Я', 'Я', 'Я', 'а', 'а', 'а', 'а', 'а', 'а', 'а', 'а', 'а', 'а', 'а', 'австрийский', 'австрийский', 'австрийского', 'австрийскому', 'австрийскому', 'австрийцев', 'австрияк', 'адъютант', 'адъютант', 'адъютант', 'адъютант', 'адъютанта', 'адъютанту', 'адъютанты', 'амуниции', 'амуницию', 'армией', 'бакенбардами', 'барабанщик', 'батальонному', 'батальонному', 'батальонный', 'батальонных', 'батюшка', 'бегать', 'без',  ...
