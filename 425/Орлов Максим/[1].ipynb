# %%
import re
import datetime
import numpy as np
import queue
#ВХОДНЫЕ ДАННЫЕ:
my_data=("максим ",2,2,2003)
disc_marks= {
    "черчение":4,
    "литература":4,
    "информатика":3,
    "алгебра":4,
    "технология":3,
    "физра":5,
    "ИЗО":5,
    "геомтерия":4,
    "история":4,
    "география":5,
    "физика":4,
    }
Aztec_Empire=["Tenoch","Acamapichtli","Huitzilihuitl","Chimalpopoca","Xihuitl Temoc","Itzcoatl","Moctezuma I","Atotoztli","Axayacatl","Tizoc","Ahuitzotl","Moctezuma II","Cuitláhuac","Cuauhtémoc","Tlacotzin","Motelchiuhtzin","Xochiquentzin","Huanitzin","Tehuetzquititzin"
              ,"Cecetzin","Cipac"]
print(len(Aztec_Empire))
family_names=["Максим","Наташа","Сергей","нина"  ]
dict_family_names={"максим":2003,"наташа":1970,"нина":1990,"Сергей":1967}
kivi_name="Барсик"
#ЗАДАНИЯ:
marks=sum(disc_marks.values())/len(disc_marks.values())
unique_name=[]
for name in family_names:
    if name in unique_name:
        continue
    else:
        unique_name.append(name)
uniq_a=[]
n=0
for sub in disc_marks:
    for i in sub:
        if i in uniq_a or i.swapcase() in sub:
            continue
        else:
            uniq_a.append(i)
    n+=(len(sub))
print("1)Средняя оценка в аттестате-",marks)
print('--------------------------------')
print("2)Уникальные имена:",*unique_name)
print('--------------------------------')
print("3)Общая длина всех названий предметов:",n)
print('--------------------------------')
print("4)Уникальные буквы в названии предметов:",uniq_a)
print('--------------------------------')
print("5)Имя пушистой кивы -",kivi_name,". В двоичной системе:")
print(bin(12))
for ch in kivi_name:
    print(bin(ord(ch)))
print('--------------------------------')
family_names.sort(reverse=True)
print("6) Отсортированный список родственников по именам:",family_names)
print('--------------------------------')
print(datetime.datetime.today())
date_old=datetime.datetime(day=my_data[1],month=my_data[2],year=my_data[3])
date=date_old
print(date)
print("7) количество дней от моей даты рождения до текущей даты",(datetime.datetime.today()-date).days)
tonex=str(input("Для продолжения введите любой символ:"))
print('--------------------------------')
print("8)FIFO очередь, в которую можно добавлять предметы по вводимому с клавиатуры индексу (до команды остановки), после введения - выводятся все;")
objects=0
q = queue.Queue()
objects=int((input(" Введите индекс который хотите добавить в очередь(0 - прекратить алгоритм): ")))
while objects!=0:
    q.put(family_names[objects])
    objects=int((input(" Введите индекс который хотите добавить в очередь(0 - прекратить алгоритм): ")))
while not q.empty():
    print(q.get(), end=' ')
print('--------------------------------')
number = (my_data[1] + my_data[2]**2 + my_data[3]) % 21 + 1
numb=int(input(": Введите индекс(1-9):"))
family_names[numb-1]=Aztec_Empire[number-1]
print("9-по введеному индексу, поменять имя в отсортированном списке родственников на имя ацтекского правителя под номером, получаемым из вашей даты рождения: number = (day + month**2 + year) % 21 + 1:",family_names)
print('--------------------------------')
print("10-создать связный список:")
#зад 10
class Node:
    def __init__(self,key, data):
        self.data = data
        self.key=key
        self.next = None
    def append(self, key,data):
        end = Node(key,data)
        n = self
        while (n.next):
            n = n.next
        n.next = end
linlist=Node(1,0+1)
i=0
n=dict_family_names.values()
dict_family_names=["максим 2003","наташа1 970","нина 1990","Сергей 1967"]
l=sorted(dict_family_names, key=lambda x: x[-4]+x[-3]+x[-2]+x[-1])
lnew=[]
for i in range(len(l)):
    lnew.append(re.sub(r'[^\w\s]+|[\d]+', r'',l[i]).strip())
print(lnew)
i=0
while i!=len(lnew):
    linlist.append(lnew[i],i+1)
    i+=1
node=linlist
while node.next:
    node = node.next
    print(node.key,node.data)
print('--------------------------------')
#зад 11:
print("11)функцию-генератор, вариант определяется как number = len(ФИО) * len (family_names) % 4:)")
numberr=len(my_data[0]) * len (family_names) % 4
print(numberr)
def gen(N):
    c=1
    a=1
    while c!=10:
        c+=1
        yield a+1
        a+=1
        a=a*(a-1)
N=10
for b in gen(N):
    print(b)
print(numberr)
# Out:
# 21
# 1)Средняя оценка в аттестате- 4.090909090909091
# --------------------------------
# 2)Уникальные имена: Максим Наташа Сергей нина
# --------------------------------
# 3)Общая длина всех названий предметов: 85
# --------------------------------
# 4)Уникальные буквы в названии предметов: ['ч', 'е', 'р', 'н', 'и', 'л', 'т', 'а', 'у', 'ф', 'о', 'м', 'к', 'г', 'б', 'х', 'я', 'з', 'И', 'З', 'О', 'с']
# --------------------------------
# 5)Имя пушистой кивы - Барсик . В двоичной системе:
# 0b1100
# 0b10000010001
# 0b10000110000
# 0b10001000000
# 0b10001000001
# 0b10000111000
# 0b10000111010
# --------------------------------
# 6) Отсортированный список родственников по именам: ['нина', 'Сергей', 'Наташа', 'Максим']
# --------------------------------
# 2023-03-27 16:34:48.136312
# 2003-02-02 00:00:00
# 7) количество дней от моей даты рождения до текущей даты 7358
# Для продолжения введите любой символ:3
# --------------------------------
# 8)FIFO очередь, в которую можно добавлять предметы по вводимому с клавиатуры индексу (до команды остановки), после введения - выводятся все;
#  Введите индекс который хотите добавить в очередь(0 - прекратить алгоритм): 2
#  Введите индекс который хотите добавить в очередь(0 - прекратить алгоритм): 3
#  Введите индекс который хотите добавить в очередь(0 - прекратить алгоритм): 0
# Наташа Максим --------------------------------
# : Введите индекс(1-9):3
# 9-по введеному индексу, поменять имя в отсортированном списке родственников на имя ацтекского правителя под номером, получаемым из вашей даты рождения: number = (day + month**2 + year) % 21 + 1: ['нина', 'Сергей', 'Tlacotzin', 'Максим']
# --------------------------------
# 10-создать связный список:
# ['наташа', 'Сергей', 'нина', 'максим']
# наташа 1
# Сергей 2
# нина 3
# максим 4
# --------------------------------
# 11)функцию-генератор, вариант определяется как number = len(ФИО) * len (family_names) % 4:)
# 0
# 2
# 3
# 7
# 43
# 1807
# 3263443
# 10650056950807
# 113423713055421844361000443
# 12864938683278671740537145998360961546653259485195807
# 0
