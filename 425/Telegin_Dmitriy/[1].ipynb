# %%
import datetime 
from collections import deque

                       
T1=("Телегин Дмитрий Сергеевич", 24, 12, 2002)
Att={'Русский язык': 4, 'Литература': 5, 'Английский': 4, 'Алгебра': 4, 'Геометрия': 4, 'Информатика': 4, 'История России': 5, 'Всеобщая история': 5, 'Обществознание': 4, 'География': 5, 'Биология': 5, 'Физика': 5, 'Астрономия': 5, 'Химия': 5}
R=['Надежда 1974', 'Лариса 1951', 'Геннадий 1950', 'Дмитрий(я) 2002', 'Сергей 1980', 'Дмитрий 1976', 'Татьяна 1979','Екатерина 2005', 'Сергей 2001']
name_k='Бобби'

                              #1 задание
s=(Att.get('Русский язык')+Att.get('Литература')+Att.get('Английский')+Att.get('Алгебра')+Att.get('Геометрия')+Att.get('Информатика')+Att.get('История России')+Att.get('Всеобщая история')+Att.get('Обществознание')+Att.get('География')+Att.get('Биология')+Att.get('Физика')+ Att.get('Астрономия')+ Att.get('Химия'))/14
print('1) Средняя оценка аттестата:', s)
print()

                              #2 задание
print('2) Уникальные имена:', list(set(R)))
print()

                              #3 задание
x=len('Русский язык')+len('Литература')+len('Английский')+len('Алгебра')+len('Геометрия')+len('Информатика')+len('История России')+len('Всеобщая история')+len('Обществознание')+len('География')+len('Биология')+len('Физика')+len('Астрономия')+len('Химия')
print('3) Общая длина всех названий предметов:', x)
print()

                              #4 задание
u = []    
for i in list(Att):                           
    u += i                              
print("4) Уникальные буквы в названиях предметов:" , set(list(u))) 
print()

                              #5 задание
d_k= ' '.join(format(x, 'b') for x in bytearray(name_k, 'utf-8'))
print('5) Имя кивы в бинарном виде:',d_k) 
print()

                              #6 задание
R.sort(reverse=True)
print('6) Отсортированный по алфавиту (в обратном порядке) список родственников:', R)
print()

                              #7 задание
today = datetime.date.today()
bday = datetime.date(2002, 12, 24)
diff = abs(bday - today)
tdiff=diff.days
print('7) Количество дней от моей даты рождения до текущей даты:', tdiff)
print()

                              #8 задание
k = int(input("Введите количество элементов в списке FIFO:"))
p = [] 

for j in range(1, k + 1):
    e_f = input("Введите элемент списка №"+str(j) +" ")
    p.append(e_f)
    
print("Введённая очередь:", p)


stop = input("Введите команду остановки: ")

while True:
    index = int(input("Введите индекс элемента: "))
    element = input("Введите элемент: ")                 
    if element == stop:
        break
    p.insert(index , element)                          
    
print("8) Полученная FIFO очередь:" , p)                   
print()

                               #9 задание
a_prav = ['Tenoch', 'Acamapochtli', 'Huitzilihitl', 'Chimalpopoca', 'Xihuitl Temoc',
            'Itzcoatl', 'Moctezuma I', 'Atotoztli', 'Axayacatl', 'Tizoc', 'Ahuitzotl',
            'Moctezuma II', 'Cuitlahuac', 'Cuauhtrmoc', 'Tlacotzin', 'Motelchiuhtzin',
            'Xochiquentzin', 'Huanitzin', 'Tehuetzquititzin', 'Cecetzin', 'Cipac']

number = (24 + 12 ** 2 + 2002) % 21 + 1
print("Индекс правителя: ", number)
print()

R.sort()       
print(R)

index = int(input("Индекс из отсортированного списка:"))

R[index] = a_prav[number]    
print("9) Список с замененным именем родственника:", R)
print() 

                               #10 задание
R_date=['Геннадий 1950', 'Лариса 1951', 'Надежда 1974', 'Дмитрий 1976', 'Татьяна 1979', 'Сергей 1980', 'Сергей 2001','Дмитрий(я) 2002', 'Екатерина 2005']
dictionary={}
for i in range(len(R_date)):
    if i==len(R_date)-1:
        dictionary[R_date[i]]=0
    else:
        dictionary[R_date[i]]=i+1
print('10) Связный список, как словарь:', dictionary)
print()

                               #11 задание
number=len('Телегин Дмитрий Сергеевич')+len('Надежда' + 'Лариса' + 'Геннадий' + 'Сергей' + 'Дмитрий'+ 'Татьяна' + 'Екатерина' + 'Сергей')
# Out:
# 1) Средняя оценка аттестата: 4.571428571428571
#
# 2) Уникальные имена: ['Геннадий 1950', 'Татьяна 1979', 'Дмитрий 1976', 'Дмитрий(я) 2002', 'Надежда 1974', 'Лариса 1951', 'Екатерина 2005', 'Сергей 2001', 'Сергей 1980']
#
# 3) Общая длина всех названий предметов: 141
#
# 4) Уникальные буквы в названиях предметов: {'и', 'О', 'к', 'Б', 'н', 'р', 'ф', 'т', 'я', 'а', 'Л', 'И', 'з', 'Г', 'в', 'г', 'й', 'А', 'щ', ' ', 'с', 'Х', 'Ф', 'Р', 'б', 'у', 'о', 'м', 'В', 'е', 'ы', 'л'}
#
# 5) Имя кивы в бинарном виде: 11010000 10010001 11010000 10111110 11010000 10110001 11010000 10110001 11010000 10111000
#
# 6) Отсортированный по алфавиту (в обратном порядке) список родственников: ['Татьяна 1979', 'Сергей 2001', 'Сергей 1980', 'Надежда 1974', 'Лариса 1951', 'Екатерина 2005', 'Дмитрий(я) 2002', 'Дмитрий 1976', 'Геннадий 1950']
#
# 7) Количество дней от моей даты рождения до текущей даты: 7434
#
# Введите количество элементов в списке FIFO:5
# Введите элемент списка №1 a
# ...
